# %%
import fitz

# %%
doc = fitz.Document(r'EGL\SB0LQTPC.PDF')

# %%
page = doc[0]

# %%
page.search_for("503200021611")
# Out:
# [Rect(160.0, 132.90200805664062, 260.7999267578125, 152.5019989013672)]

# %%
page.search_for("BOOKING CONFIRMATION / REVISE :")
page.search_for("BOOKING NO.")
page.search_for("STOWAGE CODE :")
page.search_for("FINAL DESTINATION :")
page.search_for("REMARKS")
page.search_for("QTY/TYPE")
page.search_for("GWT+TARE")
page.search_for("EST. CONNECT VSL/VOY:")
# Out:
# [Rect(54.0, 305.92999267578125, 180.0, 319.92999267578125)]

# %%
page.search_for("THESEUS")
# Out:
# [Rect(180.0, 305.92999267578125, 222.0, 319.92999267578125)]

# %%
page.get_text("words")
# Out:
# [(447.4200134277344,
#   23.579673767089844,
#   511.47357177734375,
#   40.06767654418945,
#   'BOOKING',
#   1,
#   0,
#   0),
#  (447.4200134277344,
#   41.579673767089844,
#   552.0023803710938,
#   58.06767654418945,
#   'CONFIRMATION',
#   1,
#   1,
#   0),
#  (30.0, 71.93000030517578, 66.0, 85.93000030517578, 'TO:FR.', 2, 0, 0),
#  (72.0, 71.93000030517578, 114.0, 85.93000030517578, "MEYER'S", 2, 0, 1),
#  (120.0, 71.93000030517578, 144.0, 85.93000030517578, 'SOHN', 2, 0, 2),
#  (150.0, 71.93000030517578, 180.0, 85.93000030517578, '(GMBH', 2, 0, 3),
#  (186.0, 71.93000030517578, 192.0, 85.93000030517578, '&', 2, 0, 4),
#  (198.0, 71.93000030517578, 222.0, 85.93000030517578, 'CO.)', 2, 0, 5),
#  (228.0, 71.93000030517578, 240.0, 85.93000030517578, 'KG', 2, 0, 6),
#  (246.0,
#   71.93000030517578,
#   324.0,
#   85.93000030517578,
#   'INTERNATIONAL',
#   2,
#   0,
#   7),
#  (330.0, 71.93000030517578, 384.0, 85.93000030517578, 'LOGISTICS', 2, 0, 8),
# ...
